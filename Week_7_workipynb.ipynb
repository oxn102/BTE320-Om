# %% [markdown]
# <a href="https://colab.research.google.com/github/oxn102/BTE320-Om/blob/main/Week_7_workipynb.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
numbers = []
while True:
    try:
        user_input = int(input("Enter a number (0 to stop): "))
        if user_input == 0:
            break
        numbers.append(user_input)
    except ValueError:
        print("Invalid input. Please enter a valid number.")

numbers.sort(reverse=True)
print("Your numbers in descending order:", numbers)
# Out:
# Enter a number (0 to stop): 0
# Your numbers in descending order: []

# %%
numbers = []

while True:
  num = float(input("give a number: "))
  if num == 0:
    break
  numbers.append(num)
  numbers.sort(reverse = True)
print(numbers)
# Out:
# give a number: 5
# give a number: 3
# give a number: 4
# give a number: 0
# [5.0, 4.0, 3.0]

# %%
weights = [10.0, 9.9, 10.1, 10.05]

print(sum(weights) / len(weights)) # avg weight
print(max(weights)) #largest value
print(min(weights)) #smallest value
# Out:
# 10.0125
# 10.1
# 9.9

# %%
t = (10.0, 9.9, 10.1, 10.05)
print(len(t))
print(t +(1,2,3))
print(2*t)
print(t[3])
print(t[2:6])
# Out:
# 4
# (10.0, 9.9, 10.1, 10.05, 1, 2, 3)
# (10.0, 9.9, 10.1, 10.05, 10.0, 9.9, 10.1, 10.05)
# 10.05
# (10.1, 10.05)

# %%
d = {
    "Bob":93,
    "Alice": 95,
    "Eve": 87
}
len(d)
# Out:
# 3

# %%
print(d["Eve"])
# Out:
# 87

# %%
d["Eve"] = 90
print(d)
# Out:
# {'Bob': 93, 'Alice': 95, 'Eve': 90}

# %%
d["Sam"] = 96
print(d)
# Out:
# {'Bob': 93, 'Alice': 95, 'Eve': 90, 'Sam': 96}

# %%
del d["Sam"]
print(d)
# Out:
# {'Bob': 93, 'Alice': 95, 'Eve': 90}

# %%
if "Sam" in d:
  print(d["Sam"])

# %%
d.get("Sam" , "N/A")
# Out:
# 'N/A'

# %%
d.get("Bob" , "N/A")
# Out:
# 93

# %%
d.keys()
# Out:
# dict_keys(['Bob', 'Alice', 'Eve'])

# %%
d.values()
# Out:
# dict_values([93, 95, 90])

# %%
sum(d.values()) / len(d)
# Out:
# 92.66666666666667

# %%
d.items()
# Out:
# dict_items([('Bob', 93), ('Alice', 95), ('Eve', 90)])

# %%
for key, value in d.items():
  print(key, value)
# Out:
# Bob 93
# Alice 95
# Eve 90

# %%
product_prices = {
    "P-01": 9.95,
    "P-02": 10.50
}

id = input("Enter a product ID: ")

if id in product_prices:
  print(product_prices[id])
else:
  print(f"Product {id} not found")
# Out:
# Enter a product ID: P-03
# Product P-03 not found

# %%
name_counts = {}

while True:
    try:
        N = int(input("How many names do you want to enter? "))
        if N <= 0:
            print("Please enter a positive number for N.")
        else:
            break
    except ValueError:
        print("Invalid input. Please enter an integer.")

for _ in range(N):
    name = input("Enter a name: ")
    if name in name_counts:
        name_counts[name] += 1
    else:
        name_counts[name] = 1

print("Final name counts:", name_counts)
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# /tmp/ipython-input-1186961252.py in <cell line: 0>()
#       3 while True:
#       4     try:
# ----> 5         N = int(input("How many names do you want to enter? "))
#       6         if N <= 0:
#       7             print("Please enter a positive number for N.")
#
# /usr/local/lib/python3.12/dist-packages/ipykernel/kernelbase.py in raw_input(self, prompt)
#    1175                 "raw_input was called, but this frontend does not support input requests."
#    1176             )
# -> 1177         return self._input_request(
#    1178             str(prompt),
#    1179             self._parent_ident["shell"],
#
# /usr/local/lib/python3.12/dist-packages/ipykernel/kernelbase.py in _input_request(self, prompt, ident, parent, password)
#    1217             except KeyboardInterrupt:
# ...

# %%
names ={}

while True:
  name = input ("Give a name:")
  if name in names:
    names [name] += 1
  else:
    names [name] = 1
  print(names)
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# /tmp/ipython-input-3800947270.py in <cell line: 0>()
#       2
#       3 while True:
# ----> 4   name = input ("Give a name:")
#       5   if name in names:
#       6     names [name] += 1
#
# /usr/local/lib/python3.12/dist-packages/ipykernel/kernelbase.py in raw_input(self, prompt)
#    1175                 "raw_input was called, but this frontend does not support input requests."
#    1176             )
# -> 1177         return self._input_request(
#    1178             str(prompt),
#    1179             self._parent_ident["shell"],
#
# /usr/local/lib/python3.12/dist-packages/ipykernel/kernelbase.py in _input_request(self, prompt, ident, parent, password)
#    1217             except KeyboardInterrupt:
#    1218                 # re-raise KeyboardInterrupt, to truncate traceback
# ...

# %%
set([1,1,2,1,3,4,6,6,7,8])
# Out:
# {1, 2, 3, 4, 6, 7, 8}

# %%
s1 = {1,3,5}
s2= {2,5,7}

# %%
s1.intersection(s2)
# Out:
# {5}

# %%
s1.union(s2)
# Out:
# {1, 2, 3, 5, 7}

# %%
s1.difference(s2)
# Out:
# {1, 3}

# %%
s1.symmetric_difference(s2)
# Out:
# {1, 2, 3, 7}
