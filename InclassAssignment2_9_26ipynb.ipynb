# %% [markdown]
# <a href="https://colab.research.google.com/github/oxn102/BTE320-Om/blob/main/InclassAssignment2_9_26ipynb.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
for hour in range(1,9):
  fee = 5+2.5 * hour
  if fee < 10:
    fee = 10
  elif fee > 20:
    fee = 20
  print(hour, fee)
# Out:
# 1 10
# 2 10.0
# 3 12.5
# 4 15.0
# 5 17.5
# 6 20.0
# 7 20
# 8 20

# %%
ticket= 20
init_attendees = 20
fixed_costs = 200

for ad in range (0,201,25) :
    revenue = (init_attendees + 2 * round(ad ** 0.5)) * 10
    cost = fixed_costs + ad
    profit = revenue - cost
    print(ad, profit)
# Out:
# 0 0
# 25 75
# 50 90
# 75 105
# 100 100
# 125 95
# 150 90
# 175 85
# 200 80

# %%
hour = 1
while hour < 9:
  fee = 5 + 2.5 * hour
  if fee < 10:
    fee = 10
  elif fee> 20:
    fee = 20

  print(hour, fee)
  hour += 1
# Out:
# 1 10
# 2 10.0
# 3 12.5
# 4 15.0
# 5 17.5
# 6 20.0
# 7 20
# 8 20

# %%
import math

ticket = 20
init_attendees = 20
fixed_costs = 200

ad= 0
while ad < 201:
  revenue = (init_attendees + 2 * round(math.sqrt(ad))) * 10
  costs = fixed_costs + ad
  profit = revenue - costs
  print(ad, profit)
  ad += 25
# Out:
# 0 0
# 25 75
# 50 90
# 75 105
# 100 100
# 125 95
# 150 90
# 175 85
# 200 80
