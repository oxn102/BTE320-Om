# %% [markdown]
# <a href="https://colab.research.google.com/github/oxn102/BTE320-Om/blob/main/In_Class_Assignment_3_30_2027.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# PART A- Compute Simple ROI

# %%
def roi(revenue, cost):
  assert isinstance(revenue, (int, float))
  assert isinstance(cost, (int, float))
  return (revenue - cost) / cost

# %% [markdown]
# Part B- Monthly Loan Payment

# %%
def loan_payment(principal, annual_rate, months):
  assert isinstance(principal, int)
  assert isinstance(annual_rate, float)
  assert isinstance(months, int)

  if principal <= 0 or annual_rate < 0 or months <= 0:
    raise ValueError( "Invalid input values")

  try:
    r = annual_rate / 12
    if r == 0:
      pmt = principal / months
    else:
      pmt = r * principal / (1 - (1 + r) ** (-months))
  except Exception as e:
   raise Exception(f"Error: {e}")

   return pmt
